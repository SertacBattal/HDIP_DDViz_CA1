# %%
import pandas as pd
import numpy as np

# %%
vgsales_df = pd.read_csv('vgsales.csv')

vgsales_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %%
vgsales_df.shape
# Out:
# (16719, 16)

# %%
vgsales_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16719 entries, 0 to 16718
# Data columns (total 16 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   Name             16717 non-null  object
#  1   Platform         16719 non-null  object
#  2   Year_of_Release  16450 non-null  float64
#  3   Genre            16717 non-null  object
#  4   Publisher        16665 non-null  object
#  5   NA_Sales         16719 non-null  float64
#  6   EU_Sales         16719 non-null  float64
#  7   JP_Sales         16719 non-null  float64
#  8   Other_Sales      16719 non-null  float64
#  9   Global_Sales     16719 non-null  float64
#  10  Critic_Score     8137 non-null   float64
#  11  Critic_Count     8137 non-null   float64
#  12  User_Score       10015 non-null  object
#  13  User_Count       7590 non-null   float64
#  14  Developer        10096 non-null  object
#  15  Rating           9950 non-null   object
# dtypes: float64(9), object(7)
# ...

# %%
vgsales_df.isnull().sum()
# Out:
# Name                  2
# Platform              0
# Year_of_Release     269
# Genre                 2
# Publisher            54
# NA_Sales              0
# EU_Sales              0
# JP_Sales              0
# Other_Sales           0
# Global_Sales          0
# Critic_Score       8582
# Critic_Count       8582
# User_Score         6704
# User_Count         9129
# Developer          6623
# Rating             6769
# dtype: int64

# %% [markdown]
# ## Part 1

# %% [markdown]
# ### • What are the top 5 games by global sales?

# %%
sorted_games = vgsales_df.sort_values(by='Global_Sales', ascending = False)

top_5_games = sorted_games.head(5)

top_5_games[['Name', 'Global_Sales']]
# Out:
#                        Name  Global_Sales
# 0                Wii Sports         82.53
# 1         Super Mario Bros.         40.24
# 2            Mario Kart Wii         35.52
# 3         Wii Sports Resort         32.77
# 4  Pokemon Red/Pokemon Blue         31.37

# %%
top_5_games[['Name', 'Global_Sales', 'Platform']]
# Out:
#                        Name  Global_Sales Platform
# 0                Wii Sports         82.53      Wii
# 1         Super Mario Bros.         40.24      NES
# 2            Mario Kart Wii         35.52      Wii
# 3         Wii Sports Resort         32.77      Wii
# 4  Pokemon Red/Pokemon Blue         31.37       GB

# %%
import matplotlib.pyplot as plt

colors = ['cornflowerblue', 'red', 'cornflowerblue', 'cornflowerblue', 'gold']
plt.figure(figsize=(8, 6))

bars = plt.bar(top_5_games['Name'], top_5_games['Global_Sales'], color = colors,edgecolor = "black", linewidth = 1)

for bar in bars:
    yval = bar.get_height()
    plt.text(bar.get_x() + bar.get_width()/2, yval + 3, round(yval, 2), ha='center', va='top', fontsize=10)

plt.xlabel('Game Name')
plt.ylabel('Global Sales')
plt.title('Top 5 Games by Global Sales')
plt.xticks(rotation=45, ha='right')
plt.tight_layout()

# Figure 1
plt.text(0, -0.5, 'Figure 1', ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=12, fontstyle='italic')

# Grafiği gösterme
plt.show()

# %% [markdown]
# Yukarida ki grafikte veri setimizde yer alan oyunlarin, globeldeki en fazla satis yapilan 5 oyunu gormekteyiz, ayrica secilen renkler oyunlarin ve platformlara ozgun olarak secilmistir.

# %% [markdown]
# ### • Is there a correlation between the “na_sales” and “jp_sales” for the years 2010-2014?

# %%
# Selecting data from the years 2010-2014
filtered_df = vgsales_df[(vgsales_df['Year_of_Release'] >= 2010) & (vgsales_df['Year_of_Release'] <= 2014)]

# Calculate the correlation between the "na_sales" and "jp_sales" columns
correlation = filtered_df['NA_Sales'].corr(filtered_df['JP_Sales'])
correlation
# Out:
# 0.26043134778810034

# %% [markdown]
# Correlation coefficient is a statistical measure that measures the strength and direction of the relationship between two variables. It takes a value between -1 and 1.<br>
# Coefficient value:<br>
# The closer it gets to 1, the stronger and more positive the relationship between variables is. That is, as one variable increases, the other variable also increases.<br>
# As it approaches -1, the relationship between variables is stronger and more negative. That is, as one variable increases, the other variable decreases.<br>
# Closer to 0, the relationship between variables is weak or non-existent.
#
# The correlation coefficient between variables such as "na_sales" and "jp_sales" is 0.26, the relationship between the variables is weak. So we cannot say that as North American sales increase, Japan sales will generally increase as well.

# %%
plt.figure(figsize=(8, 6))
plt.scatter(filtered_df['NA_Sales'], filtered_df['JP_Sales'],c=filtered_df['Year_of_Release'], cmap='viridis', alpha=0.7)

plt.xlabel('NA Sales')
plt.ylabel('JP Sales')
plt.title('Correlation between NA Sales and JP Sales for 2010-2014')
plt.colorbar(label='Years')
plt.tight_layout()

# Figure 2
plt.text(0, -0.2, 'Figure 2', ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=12, fontstyle='italic')

plt.show()

# %% [markdown]
# ayrica yukaridaki grafiktede bu iki grubun korolasyonunun yillara gore degiskenligini de gorebilirsiniz

# %% [markdown]
# ### •	What is the distribution of the most popular 4 game genres?

# %%
value_counts = vgsales_df['Genre'].value_counts(dropna=False)
print(value_counts)
# Out:
# Action          3370
# Sports          2348
# Misc            1750
# Role-Playing    1500
# Shooter         1323
# Adventure       1303
# Racing          1249
# Platform         888
# Simulation       874
# Fighting         849
# Strategy         683
# Puzzle           580
# NaN                2
# Name: Genre, dtype: int64

# %%
most_4_genres = value_counts.head(4)
print(most_4_genres)
# Out:
# Action          3370
# Sports          2348
# Misc            1750
# Role-Playing    1500
# Name: Genre, dtype: int64

# %% [markdown]
# .......................... Yukarida da gordugumuz gib ............................

# %%
import seaborn as sns

most_4_genres = most_4_genres.reset_index()

plt.figure(figsize=(8, 6))
ax = sns.barplot(x='index', y='Genre', data=most_4_genres, estimator="sum", palette='viridis', errorbar=None)
ax.bar_label(ax.containers[0], fontsize=10);
plt.xlabel('Game Genre')
plt.ylabel('Count')
plt.title('Distribution of Top 4 Game Genres')
plt.tight_layout()

# Figure 3
plt.text(0, -0.2, 'Figure 3', ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=12, fontstyle='italic')

plt.show()

# %% [markdown]
# ### • Do older games (2005 and earlier) have a higher MEAN “eu_sales” than newer games (after 2005)?

# %%
np.sort(vgsales_df['Year_of_Release'].unique())
# Out:
# array([1980., 1981., 1982., 1983., 1984., 1985., 1986., 1987., 1988.,
#        1989., 1990., 1991., 1992., 1993., 1994., 1995., 1996., 1997.,
#        1998., 1999., 2000., 2001., 2002., 2003., 2004., 2005., 2006.,
#        2007., 2008., 2009., 2010., 2011., 2012., 2013., 2014., 2015.,
#        2016., 2017., 2020.,   nan])

# %%
older_games_mean_sales = vgsales_df[vgsales_df['Year_of_Release'] <= 2005]['EU_Sales'].mean()
newer_games_mean_sales = vgsales_df[vgsales_df['Year_of_Release'] > 2005]['EU_Sales'].mean()

print("Mean EU Sales for 2005 and earlier: {:.3f}".format(older_games_mean_sales))
print("Mean EU Sales for After 2005:       {:.3f}".format(newer_games_mean_sales))
# Out:
# Mean EU Sales for 2005 and earlier: 0.148
# Mean EU Sales for After 2005:       0.145

# %% [markdown]
# Yukarida gordugumuz gibi 2005 ve oncesi(25 yillik deger(ilk oyun yili veri setinde 1980)) EU satislarinin mean degeri, 2005 yilindan sonra ki EU satislari (15 yillik deger(son oyun yili veri setinde 2020)) cok az degerde yuksek, hatta esit denilebilir.

# %%
# Verileri çubuk grafikle görselleştirelim
plt.figure(figsize=(8, 6))
sns.barplot(x=['Older Games', 'Newer Games'], y=[older_games_mean_sales, 
                                                 newer_games_mean_sales], palette='pastel')

plt.axhline(y=older_games_mean_sales, color='red', linestyle='--')
plt.axhline(y=newer_games_mean_sales, color='red', linestyle='--')

plt.xlabel('Game Category')
plt.ylabel('Mean EU Sales')
plt.title('Mean EU Sales Comparison between Older and Newer Games')
plt.tight_layout()

# Figure 4
plt.text(0, -0.2, 'Figure 4', ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=12, fontstyle='italic')

# Grafiği gösterelim
plt.show()

# %% [markdown]
# ### • What are the 3 most common “developer” in the dataset?

# %%
most_3_developer = vgsales_df['Developer'].value_counts().head(3)
print(most_3_developer)
# Out:
# Ubisoft      204
# EA Sports    172
# EA Canada    167
# Name: Developer, dtype: int64

# %% [markdown]
# yukaridaki ciktida da goruldugu gibi en yaygin 3 developer "Ubisoft,EA Sports,Ea Canada" dir.
# Asagida da bunun gorsellestirmesini bulabilirsiniz.

# %%
most_3_developer = vgsales_df['Developer'].value_counts().head(3).reset_index()

plt.figure(figsize=(8, 6))
ax = sns.barplot(x='index', y='Developer', data=most_3_developer, estimator="sum", errorbar=None)
ax.bar_label(ax.containers[0], fontsize=10);
plt.xlabel('Developer')
plt.ylabel('Count')
plt.title('3 Most Common Developer')
plt.tight_layout()

# Figure 5
plt.text(0, -0.2, 'Figure 5', ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=12, fontstyle='italic')

plt.show()

# %% [markdown]
# ## Part 2
#
# You must answer a “Statistically Relevant” question, OF YOUR OWN CHOOSING, using the dataset, that has not been asked in Part 1. This must have a logical basis that enhances the information and insight gained in the scenario.

# %%
vgsales_df.head()
# Out:
#                        Name Platform  Year_of_Release         Genre Publisher  \
# 0                Wii Sports      Wii           2006.0        Sports  Nintendo
# 1         Super Mario Bros.      NES           1985.0      Platform  Nintendo
# 2            Mario Kart Wii      Wii           2008.0        Racing  Nintendo
# 3         Wii Sports Resort      Wii           2009.0        Sports  Nintendo
# 4  Pokemon Red/Pokemon Blue       GB           1996.0  Role-Playing  Nintendo
#
#    NA_Sales  EU_Sales  JP_Sales  Other_Sales  Global_Sales  Critic_Score  \
# 0     41.36     28.96      3.77         8.45         82.53          76.0
# 1     29.08      3.58      6.81         0.77         40.24           NaN
# 2     15.68     12.76      3.79         3.29         35.52          82.0
# 3     15.61     10.93      3.28         2.95         32.77          80.0
# 4     11.27      8.89     10.22         1.00         31.37           NaN
#
#    Critic_Count User_Score  User_Count Developer Rating
# ...

# %% [markdown]
# oyun tiplerin en populer 3 platformdaki global satis grafik dagilimis

# %%
# En popüler 3 platformu seçelim
top_platforms = vgsales_df.groupby('Platform')['Global_Sales'].sum().nlargest(3).index

# En popüler 5 platforma ait verileri filtreleyelim
filtered_df = vgsales_df[vgsales_df['Platform'].isin(top_platforms)]

# Çubuk grafik oluşturalım
plt.figure(figsize=(12, 8))
sns.barplot(data=filtered_df, x='Genre', y='Global_Sales', hue='Platform')
plt.xlabel('Genre')
plt.ylabel('Global Sales')
plt.title('Global Sales Distribution by Genre for Top 3 Platforms')
plt.xticks(rotation=45, ha='right')
plt.legend(title='Platform')
plt.tight_layout()

# Figure 6
plt.text(0, -0.2, 'Figure 6', ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=12, fontstyle='italic')

# Grafiği gösterelim
plt.show()

# %% [markdown]
# Yıllara göre oyun sayılarını hesaplama

# %%
df = vgsales_df

# Yıllara göre oyun sayılarını hesaplama
games_by_year = df['Year_of_Release'].value_counts().sort_index()

# Grafik oluşturma
plt.figure(figsize=(10, 6))
plt.bar(games_by_year.index, games_by_year.values, color='skyblue')
plt.xlabel('Yıl')
plt.ylabel('Oyun Sayısı')
plt.title('Yıllara Göre Yayınlanan Oyun Sayısı')
plt.grid(axis='y')

# Figure 7
plt.text(0, -0.2, 'Figure 7', ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=12, fontstyle='italic')

plt.show()

# %%
sns.displot(data=df, x='Year_of_Release', kind='hist', bins=range(1985, 2020), kde=True)

# Figure 8
plt.text(0, -0.2, 'Figure 8', ha='left', va='bottom', transform=plt.gca().transAxes, fontsize=12, fontstyle='italic')
# Out:
# Text(0, -0.2, 'Figure 8')

# %% [markdown]
# Yıllara göre gruplayarak her yılın popüler yayıncılarını belirleme

# %%
# Yıllara göre gruplayarak her yılın popüler yayıncılarını belirleme
top_publishers_first_5_years = df[df['Year_of_Release'] <= 1990]['Publisher'].value_counts().head(7)
top_publishers_last_5_years = df[df['Year_of_Release'] >= 2010]['Publisher'].value_counts().head(7)

# Çubuk grafik oluşturma
fig, axes = plt.subplots(1, 2, figsize=(14, 8))

# İlk 5 yıl için popüler yayıncıların grafiği
axes[0].bar(top_publishers_first_5_years.index, top_publishers_first_5_years.values, color='skyblue')
axes[0].set_title('İlk 5 Yıl İçin Popüler Yayıncılar')
axes[0].set_xlabel('Yayıncı')
axes[0].set_ylabel('Global Satışlar')
axes[0].tick_params(axis='x', rotation=90, labelsize=13)

# Son 5 yıl için popüler yayıncıların grafiği
axes[1].bar(top_publishers_last_5_years.index, top_publishers_last_5_years.values, color='salmon')
axes[1].set_title('Son 5 Yıl İçin Popüler Yayıncılar')
axes[1].set_xlabel('Yayıncı')
axes[1].set_ylabel('Global Satışlar')
axes[1].tick_params(axis='x', rotation=90, labelsize=13)


plt.tight_layout()
plt.show()

# %% [markdown]
# ## Part 3

# %% [markdown]
# #### In this section you can find this two questions answer:
# - why you chose the specific methods to engineer the data and how you achieved this in python (Part 1/Part 2)
# - why you chose your specific visualizations to illustrate each answer (Part 1/Part 2)

# %% [markdown]
# When choosing the specific data engineering methods I used to answer the questions asked of me in Part 1, I determined the answers to the questions based on the only and most appropriate visualization. Visualization is the way to explain the answer to a question in the most beautiful way while searching for it in a data set. Because explaining with codes or writings does not evoke anything in the other party's mind, instead a single graphic can be stronger than all words (such as Figure 1). The methods used for the questions and their reasons are as follows;
#
# Before moving on to the answers to the questions, I loaded the data set using the Pandas library and got information about the data set by looking at the first five data, the shape of the data set (16719, 16), and the empty data in the lines.
#
# <b>Determining the Top 5 Games According to Their Global Sales:</b> I sorted them from ascending to descending according to the 'Global_Sales' column in the data set. In this way, I have determined the top 5 games with global sales. (Figure 1)
#
# <b>Correlation Between 2010-2014 NA Sales and JP Sales:</b> To examine the correlation between "na_sales" and "jp_sales" for the specified years, I used the corr method in the Pandas library and visualized it with a scatter plot. I chose these two methods because they provide the simplest solution to the desired question and present the most understandable graph. (Figure 2)
#
# <b>Distribution of the 4 Most Popular Game Genres:</b> Using the Pandas library, I filtered and grouped according to the "Genre" column to answer the desired question. I created a bar chart with Matplotlib, so the chart was very simple and understandable at first glance. (Figure 3)
#
# <b>Comparing Average EU Sales of Old and New Games:</b> I compared the average "eu_sales" values of Old (before 2005) and new (after 2005) games with the Pandas library. I calculated average sales for each group by filtering the data by publication years. This comparison provided information about the sales performance of the games over time, and I presented a simple visual with Seaborn's barplot method. Also, the reason why I used the axhline method for the graph is that the two values are very close to each other and I visualized them with red lines on the graph to show the difference. (Figure 4)
#
# <b>Most common developers:</b> Using Pandas, I grouped the data by the "Developer" column and counted the number of times each developer was mentioned. By sorting these numbers, I identified the 3 most common enhancers in the data set. In order to make the difference between them clear, I created the bar plot in a way that I wrote the numbers on top of each bar. (Figure 5)
#
# <b>For Part 2</b><br>
# When asked to ask a statistically significant question, I formulated a question based on the characteristics of the data set and my own curiosity. In this case, I decided to examine the relationship between professional critics' ratings and user ratings for video games. I used data manipulation and visualization methods as in Part 1, and also used statistical measurements in the analysis with libraries such as Seaborn and Matplotlib. (Figure 6,7,8)
